# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import h5py
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
PROJECT_PATH = '../'
import sys
sys.path.insert(0, PROJECT_PATH)

# %%
from PIML.box.boxWR import BoxWR

# %%
b = BoxWR()

# %%
W="RedM"; R="G"; Res=5000;step=10;
b.init(W,R, Res,step, onPCA=1)
# Out:
# #220 R=1000.00
# (2204,) (220,)
# sky_H (2204,)
# snr2nl-SN [216.6386881078599, 203.01082022175686, 175.41796144691997, 124.52102085089179, 96.4449364832021, 76.06048046199851, 60.41932438849117, 30.820835338248834, 16.111019417723767, 6.691918127809355, 4.231170906403184]
# Top10 eigs [87.34 10.1   6.69  2.38  1.65  1.35  0.85  0.79  0.68  0.53]
# Building RBF with gaussan kernel on data shape (5880,)
# Building RBF with gaussan kernel on data shape (5880, 10)

# %%
NL, NL2 = 100, 30
b.estimate_snr(NL), b.estimate_snr(NL2)
# Out:
# (6.392926056533718, 20.409148419484623)

# %%
diff_10k_100, bias_10k_100,bX = b.eval_pca_bias(b.PhyMid, 10000, noise_level=NL)
# diff_10k_30, bias_10k_30 = b.eval_pca_bias(b.PhyMid, 10000, noise_level=NL2)
# diff_1M_100, bias_1M_100 = b.eval_pca_bias(b.PhyMid, 1000000, noise_level=NL)
# Out:
# noise_level 100

# %%
diffs = [diff_10k_100, diff_10k_30, diff_1M_100]

# %%
b.plot_bias_evals(diffs, bias_1M_100, bX,pmt=None, diff_labels=["SN10_10k","SN30_10k","SN10_1M"])

# %%
b.save_ak()
